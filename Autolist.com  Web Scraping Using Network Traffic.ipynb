# %% [markdown]
# # Autolist.com  Web Scraping using network traffic

# %% [markdown]
# ![](https://i.imgur.com/di54DTP.jpg)

# %% [markdown]
# ## 1. Introduction :

# %% [markdown]
# ### 1.1. What is web scraping

# %% [markdown]
# Web scraping is the process of collecting structured web data in an automated fashion. Some of the main use cases of web scraping include price monitoring, price intelligence, news monitoring, lead generation, and market research among many others.
#
# In general, web data extraction is used by people and businesses who want to make use of the vast amount of publicly available web data to make smarter decisions.
#
# There are a number of tools and methods for performing web scraping; using network traffic, Scrappy, Selenium and Beautiful Soup are the most popular methods.

# %% [markdown]
# ### 1.2. Tools used in this project

# %% [markdown]
# Most scraping projects use Beautiful Soup but using network traffic can also be used to get the information we need
#
# In this project, we are going to use Python as our coding language to scrape.
#
# In Python, We will mainly use Requests library to get the information from the websites.
#
# Then the information that has been scrapped will be turned into a Pandas DataFrame and then
# we are going to save the file as CSV.

# %% [markdown]
# ## 2. Project Steps:

# %% [markdown]
# - assessing the website to find the information we need
# - copying as cURL and turning to python
# - using request to download the information
# - extracting info for one item
# - putting it all together and get the information automatically

# %% [markdown]
# ### 2.1. assessing the website to find the information we need

# %% [markdown]
# In order to get the information we need we are going to right click and use inspect to go to the source
#
# Under Network tab we can see there is fetch/XHR tab. while we scroll on the page the info gets populated

# %% [markdown]
# ![](https://i.imgur.com/EYL7FMZ.jpg)

# %% [markdown]
# we need to check the items under the Name column and find the information we need
#
# This part is a trial and error until we find the part we need

# %% [markdown]
# ![](https://i.imgur.com/od1F1Oz.jpg)

# %% [markdown]
# ### 2.2 copying as cURL and turning to python

# %% [markdown]
# After we have found the right object, we should right click on the object and then Copy - Copy as cURL(cmd)

# %% [markdown]
# Then we need a cURL converter to turn it into a python format
# we can use curl.trillworks.com
#
# after converting that we will bring the python version to jupyter notebook and continue the project

# %%
# Importing necessary libraries

import requests
import pandas as pd

# %% [markdown]
# ### 2.3 using request to download the information

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'a05719cf-a626-4dee-bb98-bef4f39d375c',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzkyLjAuNDUxNS4xNTkgU2FmYXJpLzUzNy4zNiJ9; client_guid_timestamp=e02c9c83-67cd-4781-9710-2a0fb9ca8e20.1629563935984; scavenger-a493=...; _sp_ses.8ca5=*; _fbp=fb.1.1629563936393.301782673; _ga=GA1.2.1962975142.1629563934; _gid=GA1.2.809253866.1629563937; __gads=ID=2fecf3c5f98db8bc:T=1629563936:S=ALNI_MbP7Qh5aV67Y9ME82H_NbgP-TB1lg; _ga_152345333=GS1.1.1629563933.1.1.1629563988.0; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=c9711a73-266d-4daa-8d34-a5f4b1050171; _gcl_au=1.1.1968340282.1629564101; cto_bundle=e7B8Fl94MDdzUjRmcjFBSlZrekd2TyUyRmNzdEZYR0hiM3FNWVFYSHBqbUtJMjJVYzFNOERnOFBSelQlMkZIT3o4Z2Z2RjA0SCUyQjdmJTJCVVhBZmZnRUlFRERqUFp5NlBrVksxWjhsekp2b3ZSMm1UMHc1ajklMkZVbnoyS2lOYklnNVRiSmNTVSUyRlpnJTJCenRRd01nU1BSd2JGelFZNXZJQXNMZyUzRCUzRA; _gat=1; _sp_id.8ca5=c99d8079-5160-4a37-9ca1-0ef78843c81f.1629563936.1.1629564425.1629563936.faa2eb1c-9606-4e57-ab87-742b8c6e8ca9',
    'if-none-match': 'W/^\\^8dcb08c3d726a06db127e8ed93cf14d4^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San^%^20Francisco,^%^20CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '2'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %%
# checking if the request response was successful
response
# Out:
# <Response [200]>

# %%
# creating a json object from the response we got from page 
json_response =response.json()
json_response
#check a couple of books to see we have the file
# Out:
# {'total_results_count': 168,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2022,
#   'age_type': 'new',
#   'app': 'web'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1623286982,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6KF483326',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6KF483326',
#    'clickoff_url': 'https://www.shift.com/car/c110936?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 220874699,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--1kW4bu47--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$40,500',
#    'price_unformatted': 40500,
#    'mileage': '16,341 Miles',
#    'mileage_unformatted': 16341,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA6KF483326',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '304931331',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c110936',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1629524358,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB8MF864123',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8MF864123',
#    'clickoff_url': 'https://www.carmax.com/car/20993520?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 225915414,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20993520/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--mNos6IWe--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20993520/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.6782548370533,
#    'lon': -121.912967630505,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$54,998',
#    'price_unformatted': 54998,
#    'mileage': '1,339 Miles',
#    'mileage_unformatted': 1339,
#    'city': 'Pleasanton',
#    'state': 'CA',
#    'distance_from_origin': 28,
#    'dealer_name': 'CarMax Pleasanton - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB8MF864123',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB8MF864123',
#     'remote_dealer_id': '6068',
#     'dealer_name': 'CarMax Pleasanton',
#     'remote_sku': '20993520',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_pleasanton',
#     'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627441173,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2KF412978',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF412978',
#    'clickoff_url': 'https://www.shift.com/car/c1984364?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224254796,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/27/18/26/2019_tesla_model_3-pic-8870853144196450115-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ejucJ6Zp--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/27/18/26/2019_tesla_model_3-pic-8870853144196450115-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$41,950',
#    'price_unformatted': 41950,
#    'mileage': '32,407 Miles',
#    'mileage_unformatted': 32407,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2KF412978',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308789724',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1984364',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1629852094,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA0JF158699',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0JF158699',
#    'clickoff_url': 'https://www.shift.com/car/c130303?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226113236,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/24/17/40/2018_tesla_model_3-pic-3429287276583885868-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--6vhyjSkS--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/24/17/40/2018_tesla_model_3-pic-3429287276583885868-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$39,950',
#    'price_unformatted': 39950,
#    'mileage': '46,517 Miles',
#    'mileage_unformatted': 46517,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA0JF158699',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '310913510',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c130303',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1628006297,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA8JF006413',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8JF006413',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224721117,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/03/01/30/2018_tesla_model_3-pic-7442314322474281858-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--dpbSZnfy--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/03/01/30/2018_tesla_model_3-pic-7442314322474281858-1024x768.jpeg',
#    'lat': 37.3233,
#    'lon': -121.958,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$46,999',
#    'price_unformatted': 46999,
#    'mileage': '9,350 Miles',
#    'mileage_unformatted': 9350,
#    'city': 'San Jose',
#    'state': 'CA',
#    'distance_from_origin': 40,
#    'dealer_name': 'San Jose Mitsubishi',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA8JF006413',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '309339601',
#     'remote_dealer_id': '439186',
#     'dealer_name': None,
#     'remote_sku': '10765',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1629851436,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEEXLF049478',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEEXLF049478',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226111768,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/25/18/49/2020_tesla_model_y-pic-5301502706437901554-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--rCZz49jM--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/25/18/49/2020_tesla_model_y-pic-5301502706437901554-1024x768.jpeg',
#    'lat': 37.4982,
#    'lon': -121.974,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$62,995',
#    'price_unformatted': 62995,
#    'mileage': '17,245 Miles',
#    'mileage_unformatted': 17245,
#    'city': 'Fremont',
#    'state': 'CA',
#    'distance_from_origin': 30,
#    'dealer_name': 'Premier Nissan Of Fremont',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJYGDEEXLF049478',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '310928052',
#     'remote_dealer_id': '279286',
#     'dealer_name': None,
#     'remote_sku': 'P9097',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1629178489,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EC3LF601917',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EC3LF601917',
#    'clickoff_url': 'https://www.carmax.com/car/20726247?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 225609016,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20726247/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--SltMIHQH--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20726247/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 38.3941458192144,
#    'lon': -122.742670099023,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$58,998',
#    'price_unformatted': 58998,
#    'mileage': '17,796 Miles',
#    'mileage_unformatted': 17796,
#    'city': 'Santa Rosa',
#    'state': 'CA',
#    'distance_from_origin': 46,
#    'dealer_name': 'CarMax Santa Rosa - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EC3LF601917',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EC3LF601917',
#     'remote_dealer_id': '6077',
#     'dealer_name': 'CarMax Santa Rosa',
#     'remote_sku': '20726247',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_santa_rosa',
#     'dealer_uuid': '65995b5c-37dd-4c3e-9d1f-1e4cddf4565c',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1629908833,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB7KF393756',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7KF393756',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226179149,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/25/01/10/2019_tesla_model_3-pic-7526808910291261178-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--WYCzUDQv--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/25/01/10/2019_tesla_model_3-pic-7526808910291261178-1024x768.jpeg',
#    'lat': 37.9659,
#    'lon': -122.052,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$57,990',
#    'price_unformatted': 57990,
#    'mileage': '6,416 Miles',
#    'mileage_unformatted': 6416,
#    'city': 'Concord',
#    'state': 'CA',
#    'distance_from_origin': 23,
#    'dealer_name': 'Elite Motor Cars',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EB7KF393756',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '310980907',
#     'remote_dealer_id': '385937',
#     'dealer_name': None,
#     'remote_sku': '005944',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Performance',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1629869677,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EC6LF640954',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EC6LF640954',
#    'clickoff_url': 'https://www.carmax.com/car/21038068?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226133083,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21038068/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Ss5rU2Tx--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21038068/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.500874,
#    'lon': -121.966481,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$61,998',
#    'price_unformatted': 61998,
#    'mileage': '10,353 Miles',
#    'mileage_unformatted': 10353,
#    'city': 'Fremont',
#    'state': 'CA',
#    'distance_from_origin': 31,
#    'dealer_name': 'CarMax Fremont - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EC6LF640954',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EC6LF640954',
#     'remote_dealer_id': '6071',
#     'dealer_name': 'CarMax Fremont',
#     'remote_sku': '21038068',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fremont',
#     'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1629738105,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA4KF190413',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA4KF190413',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226049903,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/25/22/02/2019_tesla_model_3-pic-7089523766951612823-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s---bvRrS5R--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/25/22/02/2019_tesla_model_3-pic-7089523766951612823-1024x768.jpeg',
#    'lat': 37.7488,
#    'lon': -122.204,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$42,598',
#    'price_unformatted': 42598,
#    'mileage': '21,219 Miles',
#    'mileage_unformatted': 21219,
#    'city': 'Oakland',
#    'state': 'CA',
#    'distance_from_origin': 11,
#    'dealer_name': 'Audi Oakland',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA4KF190413',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '309892457',
#     'remote_dealer_id': '63786',
#     'dealer_name': None,
#     'remote_sku': 'KF190413T',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Mid Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1629765619,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJXCDE22JF112969',
#    'vdp_url': '/tesla-model+x#vin=5YJXCDE22JF112969',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226052963,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/24/12/44/2018_tesla_model_x-pic-3439673715318300750-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Q2EUFj-M--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/24/12/44/2018_tesla_model_x-pic-3439673715318300750-1024x768.jpeg',
#    'lat': 37.4982,
#    'lon': -121.974,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model X',
#    'model_id': 2101,
#    'display_color': '',
#    'price': '$77,995',
#    'price_unformatted': 77995,
#    'mileage': '22,892 Miles',
#    'mileage_unformatted': 22892,
#    'city': 'Fremont',
#    'state': 'CA',
#    'distance_from_origin': 30,
#    'dealer_name': 'Premier Nissan Of Fremont',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJXCDE22JF112969',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '310851023',
#     'remote_dealer_id': '279286',
#     'dealer_name': None,
#     'remote_sku': 'P9085',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': '75D',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1629858908,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB1MF926929',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB1MF926929',
#    'clickoff_url': 'https://www.carmax.com/car/21078812?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226131760,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21078812/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Cn28x3K4--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21078812/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.5061326706153,
#    'lon': -121.965889235115,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$55,998',
#    'price_unformatted': 55998,
#    'mileage': '5,922 Miles',
#    'mileage_unformatted': 5922,
#    'city': 'Fremont',
#    'state': 'CA',
#    'distance_from_origin': 30,
#    'dealer_name': 'CarMax Fremont - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB1MF926929',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB1MF926929',
#     'remote_dealer_id': '6071',
#     'dealer_name': 'CarMax Fremont',
#     'remote_sku': '21078812',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fremont',
#     'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1629908833,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJXCDE2XJF141846',
#    'vdp_url': '/tesla-model+x#vin=5YJXCDE2XJF141846',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226179150,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/25/01/10/2018_tesla_model_x-pic-6804393804381296408-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--_cpFTEVz--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/25/01/10/2018_tesla_model_x-pic-6804393804381296408-1024x768.jpeg',
#    'lat': 37.9659,
#    'lon': -122.052,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model X',
#    'model_id': 2101,
#    'display_color': '',
#    'price': '$80,990',
#    'price_unformatted': 80990,
#    'mileage': '23,731 Miles',
#    'mileage_unformatted': 23731,
#    'city': 'Concord',
#    'state': 'CA',
#    'distance_from_origin': 23,
#    'dealer_name': 'Elite Motor Cars',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJXCDE2XJF141846',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '310981041',
#     'remote_dealer_id': '385937',
#     'dealer_name': None,
#     'remote_sku': '005942',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': '100D',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1629813229,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6LF632710',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6LF632710',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226064618,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/24/23/39/2020_tesla_model_3-pic-5586592617397235030-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4Lekyv4I--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/24/23/39/2020_tesla_model_3-pic-5586592617397235030-1024x768.jpeg',
#    'lat': 37.816,
#    'lon': -122.264,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$46,900',
#    'price_unformatted': 46900,
#    'mileage': '12,539 Miles',
#    'mileage_unformatted': 12539,
#    'city': 'Oakland',
#    'state': 'CA',
#    'distance_from_origin': 8,
#    'dealer_name': 'Volkswagen Of Oakland',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA6LF632710',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '310884683',
#     'remote_dealer_id': '264197',
#     'dealer_name': None,
#     'remote_sku': 'V6038',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 229,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1629392195,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA8KF361650',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8KF361650',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 225807415,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/20/05/02/2019_tesla_model_3-pic-7215219798033276304-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--d-M4fXkL--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/20/05/02/2019_tesla_model_3-pic-7215219798033276304-1024x768.jpeg',
#    'lat': 37.7528,
#    'lon': -122.209,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$40,480',
#    'price_unformatted': 40480,
#    'mileage': '46,334 Miles',
#    'mileage_unformatted': 46334,
#    'city': 'Oakland',
#    'state': 'CA',
#    'distance_from_origin': 11,
#    'dealer_name': 'Oakland Acura',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA8KF361650',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '310539788',
#     'remote_dealer_id': '59912',
#     'dealer_name': None,
#     'remote_sku': '12229',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 229,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1628178015,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1E22GF128581',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1E22GF128581',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224868860,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/16/01/51/2016_tesla_model_s-pic-21583226465528964-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--JPpSd0lM--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/16/01/51/2016_tesla_model_s-pic-21583226465528964-1024x768.jpeg',
#    'lat': 37.700083,
#    'lon': -121.806922,
#    'year': 2016,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$59,995',
#    'price_unformatted': 59995,
#    'mileage': '23,687 Miles',
#    'mileage_unformatted': 23687,
#    'city': 'Livermore',
#    'state': 'CA',
#    'distance_from_origin': 33,
#    'dealer_name': 'Livermore Ford Lincoln',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJSA1E22GF128581',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '309518509',
#     'remote_dealer_id': '286449',
#     'dealer_name': None,
#     'remote_sku': 'P8618',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': '60D',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1629556087,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJXCAE23GF006652',
#    'vdp_url': '/tesla-model+x#vin=5YJXCAE23GF006652',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 225927079,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/21/04/18/2016_tesla_model_x-pic-1471908417969702557-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--tL0vIE6e--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/21/04/18/2016_tesla_model_x-pic-1471908417969702557-1024x768.jpeg',
#    'lat': 37.5043,
#    'lon': -122.248,
#    'year': 2016,
#    'make': 'Tesla',
#    'model': 'Model X',
#    'model_id': 2101,
#    'display_color': '',
#    'price': '$69,799',
#    'price_unformatted': 69799,
#    'mileage': '42,976 Miles',
#    'mileage_unformatted': 42976,
#    'city': 'San Carlos',
#    'state': 'CA',
#    'distance_from_origin': 20,
#    'dealer_name': 'Z CARZ INC',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJXCAE23GF006652',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '310744852',
#     'remote_dealer_id': '343090',
#     'dealer_name': None,
#     'remote_sku': 'Z5328',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': '90D',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1622731589,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJXCDE26KF182783',
#    'vdp_url': '/tesla-model+x#vin=5YJXCDE26KF182783',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 220394830,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/05/22/01/2019_tesla_model_x-pic-4929792636896690341-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--DAhc72uU--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/05/22/01/2019_tesla_model_x-pic-4929792636896690341-1024x768.jpeg',
#    'lat': 37.2793687062809,
#    'lon': -121.95494149607,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model X',
#    'model_id': 2101,
#    'display_color': '',
#    'price': '$79,899',
#    'price_unformatted': 79899,
#    'mileage': '9,108 Miles',
#    'mileage_unformatted': 9108,
#    'city': 'Campbell',
#    'state': 'CA',
#    'distance_from_origin': 42,
#    'dealer_name': 'Prestige Pre-Owned',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJXCDE26KF182783',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '304373975',
#     'remote_dealer_id': '341863',
#     'dealer_name': None,
#     'remote_sku': 'Consign',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Standard Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1627834723,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA3KF446556',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3KF446556',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224636651,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/15/05/46/2019_tesla_model_3-pic-7327959515489823717-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--kjvdAU1---/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/15/05/46/2019_tesla_model_3-pic-7327959515489823717-1024x768.jpeg',
#    'lat': 37.5879,
#    'lon': -122.362,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$39,500',
#    'price_unformatted': 39500,
#    'mileage': '18,982 Miles',
#    'mileage_unformatted': 18982,
#    'city': 'Burlingame',
#    'state': 'CA',
#    'distance_from_origin': 13,
#    'dealer_name': 'Porsche Audi Burlingame',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA3KF446556',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '309259156',
#     'remote_dealer_id': '312434',
#     'dealer_name': None,
#     'remote_sku': '2130B',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1628697305,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1H12EFP29862',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1H12EFP29862',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 225255947,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/11/03/20/2014_tesla_model_s-pic-2538277380164200276-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HxUp26kR--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/11/03/20/2014_tesla_model_s-pic-2538277380164200276-1024x768.jpeg',
#    'lat': 37.9367,
#    'lon': -122.051,
#    'year': 2014,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$35,950',
#    'price_unformatted': 35950,
#    'mileage': '134,940 Miles',
#    'mileage_unformatted': 134940,
#    'city': 'Walnut Creek',
#    'state': 'CA',
#    'distance_from_origin': 22,
#    'dealer_name': 'Walnut Creek Motor Cars',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJSA1H12EFP29862',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '309944708',
#     'remote_dealer_id': '370667',
#     'dealer_name': None,
#     'remote_sku': '2147',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': '85',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True}],
#  'html': {'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EA6KF483326"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--1kW4bu47--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg)\' title=\'used 2019 Tesla Model 3 Standard Range Plus White 5YJ3E1EA6KF483326\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2019 Tesla Model 3 Standard Range Plus</div>\n<div class=\'subtext\'>\n16,341 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Online Only</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$40,500</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $584/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EB8MF864123"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--mNos6IWe--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20993520/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a)\' title=\'used 2021 Tesla Model 3 Long Range Gray 5YJ3E1EB8MF864123\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2021 Tesla Model 3 Long Range</div>\n<div class=\'subtext\'>\n1,339 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Pleasanton, CA</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$54,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $793/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EA2KF412978"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.autolist.com/image/fetch/s--ejucJ6Zp-- ...
#   'pagination': '<ul><li data-page="1" class="previous"><a>Previous</a></li><li data-page="1"><a>1</a></li><li class="selected"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="7"><a>7</a></li><li data-page="8"><a>8</a></li><li data-page="3" class="next"><a>Next</a></li></ul>'}}

# %%
# check what type of object is our json

type(json_response)
# Out:
# dict

# %%
json_response.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# the same number of keys as the ones in the network header in page. the info we need as shown on the page is in "search_results" key values

# %% [markdown]
# ### 2.4 extracting info for one item

# %%
# the information we are going to get from the json is :
# model
# mileage
# year
# dealer name
# price

# %%
results_json =json_response["search_results"]
results_json
# Out:
# [{'available_nationwide': False,
#   'created_at': 1623286982,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA6KF483326',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6KF483326',
#   'clickoff_url': 'https://www.shift.com/car/c110936?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 220874699,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--1kW4bu47--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$40,500',
#   'price_unformatted': 40500,
#   'mileage': '16,341 Miles',
#   'mileage_unformatted': 16341,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA6KF483326',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '304931331',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c110936',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1629524358,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB8MF864123',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8MF864123',
#   'clickoff_url': 'https://www.carmax.com/car/20993520?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 225915414,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20993520/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--mNos6IWe--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20993520/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.6782548370533,
#   'lon': -121.912967630505,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$54,998',
#   'price_unformatted': 54998,
#   'mileage': '1,339 Miles',
#   'mileage_unformatted': 1339,
#   'city': 'Pleasanton',
#   'state': 'CA',
#   'distance_from_origin': 28,
#   'dealer_name': 'CarMax Pleasanton - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB8MF864123',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB8MF864123',
#    'remote_dealer_id': '6068',
#    'dealer_name': 'CarMax Pleasanton',
#    'remote_sku': '20993520',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_pleasanton',
#    'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627441173,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2KF412978',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF412978',
#   'clickoff_url': 'https://www.shift.com/car/c1984364?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224254796,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/27/18/26/2019_tesla_model_3-pic-8870853144196450115-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ejucJ6Zp--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/27/18/26/2019_tesla_model_3-pic-8870853144196450115-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$41,950',
#   'price_unformatted': 41950,
#   'mileage': '32,407 Miles',
#   'mileage_unformatted': 32407,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA2KF412978',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308789724',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1984364',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1629852094,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA0JF158699',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0JF158699',
#   'clickoff_url': 'https://www.shift.com/car/c130303?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226113236,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/24/17/40/2018_tesla_model_3-pic-3429287276583885868-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--6vhyjSkS--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/24/17/40/2018_tesla_model_3-pic-3429287276583885868-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$39,950',
#   'price_unformatted': 39950,
#   'mileage': '46,517 Miles',
#   'mileage_unformatted': 46517,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA0JF158699',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '310913510',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c130303',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1628006297,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA8JF006413',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8JF006413',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224721117,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/03/01/30/2018_tesla_model_3-pic-7442314322474281858-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--dpbSZnfy--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/03/01/30/2018_tesla_model_3-pic-7442314322474281858-1024x768.jpeg',
#   'lat': 37.3233,
#   'lon': -121.958,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$46,999',
#   'price_unformatted': 46999,
#   'mileage': '9,350 Miles',
#   'mileage_unformatted': 9350,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 40,
#   'dealer_name': 'San Jose Mitsubishi',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA8JF006413',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '309339601',
#    'remote_dealer_id': '439186',
#    'dealer_name': None,
#    'remote_sku': '10765',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1629851436,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEEXLF049478',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEEXLF049478',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226111768,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/25/18/49/2020_tesla_model_y-pic-5301502706437901554-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--rCZz49jM--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/25/18/49/2020_tesla_model_y-pic-5301502706437901554-1024x768.jpeg',
#   'lat': 37.4982,
#   'lon': -121.974,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$62,995',
#   'price_unformatted': 62995,
#   'mileage': '17,245 Miles',
#   'mileage_unformatted': 17245,
#   'city': 'Fremont',
#   'state': 'CA',
#   'distance_from_origin': 30,
#   'dealer_name': 'Premier Nissan Of Fremont',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJYGDEEXLF049478',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '310928052',
#    'remote_dealer_id': '279286',
#    'dealer_name': None,
#    'remote_sku': 'P9097',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1629178489,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EC3LF601917',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EC3LF601917',
#   'clickoff_url': 'https://www.carmax.com/car/20726247?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 225609016,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20726247/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--SltMIHQH--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20726247/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 38.3941458192144,
#   'lon': -122.742670099023,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$58,998',
#   'price_unformatted': 58998,
#   'mileage': '17,796 Miles',
#   'mileage_unformatted': 17796,
#   'city': 'Santa Rosa',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'CarMax Santa Rosa - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EC3LF601917',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EC3LF601917',
#    'remote_dealer_id': '6077',
#    'dealer_name': 'CarMax Santa Rosa',
#    'remote_sku': '20726247',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_santa_rosa',
#    'dealer_uuid': '65995b5c-37dd-4c3e-9d1f-1e4cddf4565c',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1629908833,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB7KF393756',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7KF393756',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226179149,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/25/01/10/2019_tesla_model_3-pic-7526808910291261178-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--WYCzUDQv--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/25/01/10/2019_tesla_model_3-pic-7526808910291261178-1024x768.jpeg',
#   'lat': 37.9659,
#   'lon': -122.052,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$57,990',
#   'price_unformatted': 57990,
#   'mileage': '6,416 Miles',
#   'mileage_unformatted': 6416,
#   'city': 'Concord',
#   'state': 'CA',
#   'distance_from_origin': 23,
#   'dealer_name': 'Elite Motor Cars',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EB7KF393756',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '310980907',
#    'remote_dealer_id': '385937',
#    'dealer_name': None,
#    'remote_sku': '005944',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Performance',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1629869677,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EC6LF640954',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EC6LF640954',
#   'clickoff_url': 'https://www.carmax.com/car/21038068?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226133083,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21038068/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Ss5rU2Tx--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21038068/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.500874,
#   'lon': -121.966481,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$61,998',
#   'price_unformatted': 61998,
#   'mileage': '10,353 Miles',
#   'mileage_unformatted': 10353,
#   'city': 'Fremont',
#   'state': 'CA',
#   'distance_from_origin': 31,
#   'dealer_name': 'CarMax Fremont - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EC6LF640954',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EC6LF640954',
#    'remote_dealer_id': '6071',
#    'dealer_name': 'CarMax Fremont',
#    'remote_sku': '21038068',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_fremont',
#    'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1629738105,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA4KF190413',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA4KF190413',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226049903,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/25/22/02/2019_tesla_model_3-pic-7089523766951612823-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s---bvRrS5R--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/25/22/02/2019_tesla_model_3-pic-7089523766951612823-1024x768.jpeg',
#   'lat': 37.7488,
#   'lon': -122.204,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$42,598',
#   'price_unformatted': 42598,
#   'mileage': '21,219 Miles',
#   'mileage_unformatted': 21219,
#   'city': 'Oakland',
#   'state': 'CA',
#   'distance_from_origin': 11,
#   'dealer_name': 'Audi Oakland',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA4KF190413',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '309892457',
#    'remote_dealer_id': '63786',
#    'dealer_name': None,
#    'remote_sku': 'KF190413T',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Mid Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1629765619,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCDE22JF112969',
#   'vdp_url': '/tesla-model+x#vin=5YJXCDE22JF112969',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226052963,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/24/12/44/2018_tesla_model_x-pic-3439673715318300750-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Q2EUFj-M--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/24/12/44/2018_tesla_model_x-pic-3439673715318300750-1024x768.jpeg',
#   'lat': 37.4982,
#   'lon': -121.974,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$77,995',
#   'price_unformatted': 77995,
#   'mileage': '22,892 Miles',
#   'mileage_unformatted': 22892,
#   'city': 'Fremont',
#   'state': 'CA',
#   'distance_from_origin': 30,
#   'dealer_name': 'Premier Nissan Of Fremont',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCDE22JF112969',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '310851023',
#    'remote_dealer_id': '279286',
#    'dealer_name': None,
#    'remote_sku': 'P9085',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '75D',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1629858908,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB1MF926929',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB1MF926929',
#   'clickoff_url': 'https://www.carmax.com/car/21078812?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226131760,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21078812/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Cn28x3K4--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21078812/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.5061326706153,
#   'lon': -121.965889235115,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$55,998',
#   'price_unformatted': 55998,
#   'mileage': '5,922 Miles',
#   'mileage_unformatted': 5922,
#   'city': 'Fremont',
#   'state': 'CA',
#   'distance_from_origin': 30,
#   'dealer_name': 'CarMax Fremont - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB1MF926929',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB1MF926929',
#    'remote_dealer_id': '6071',
#    'dealer_name': 'CarMax Fremont',
#    'remote_sku': '21078812',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_fremont',
#    'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1629908833,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCDE2XJF141846',
#   'vdp_url': '/tesla-model+x#vin=5YJXCDE2XJF141846',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226179150,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/25/01/10/2018_tesla_model_x-pic-6804393804381296408-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--_cpFTEVz--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/25/01/10/2018_tesla_model_x-pic-6804393804381296408-1024x768.jpeg',
#   'lat': 37.9659,
#   'lon': -122.052,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$80,990',
#   'price_unformatted': 80990,
#   'mileage': '23,731 Miles',
#   'mileage_unformatted': 23731,
#   'city': 'Concord',
#   'state': 'CA',
#   'distance_from_origin': 23,
#   'dealer_name': 'Elite Motor Cars',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCDE2XJF141846',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '310981041',
#    'remote_dealer_id': '385937',
#    'dealer_name': None,
#    'remote_sku': '005942',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '100D',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1629813229,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA6LF632710',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6LF632710',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226064618,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/24/23/39/2020_tesla_model_3-pic-5586592617397235030-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4Lekyv4I--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/24/23/39/2020_tesla_model_3-pic-5586592617397235030-1024x768.jpeg',
#   'lat': 37.816,
#   'lon': -122.264,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$46,900',
#   'price_unformatted': 46900,
#   'mileage': '12,539 Miles',
#   'mileage_unformatted': 12539,
#   'city': 'Oakland',
#   'state': 'CA',
#   'distance_from_origin': 8,
#   'dealer_name': 'Volkswagen Of Oakland',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA6LF632710',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '310884683',
#    'remote_dealer_id': '264197',
#    'dealer_name': None,
#    'remote_sku': 'V6038',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 229,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1629392195,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA8KF361650',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8KF361650',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 225807415,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/20/05/02/2019_tesla_model_3-pic-7215219798033276304-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--d-M4fXkL--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/20/05/02/2019_tesla_model_3-pic-7215219798033276304-1024x768.jpeg',
#   'lat': 37.7528,
#   'lon': -122.209,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$40,480',
#   'price_unformatted': 40480,
#   'mileage': '46,334 Miles',
#   'mileage_unformatted': 46334,
#   'city': 'Oakland',
#   'state': 'CA',
#   'distance_from_origin': 11,
#   'dealer_name': 'Oakland Acura',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA8KF361650',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '310539788',
#    'remote_dealer_id': '59912',
#    'dealer_name': None,
#    'remote_sku': '12229',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 229,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1628178015,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E22GF128581',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E22GF128581',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224868860,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/16/01/51/2016_tesla_model_s-pic-21583226465528964-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--JPpSd0lM--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/16/01/51/2016_tesla_model_s-pic-21583226465528964-1024x768.jpeg',
#   'lat': 37.700083,
#   'lon': -121.806922,
#   'year': 2016,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$59,995',
#   'price_unformatted': 59995,
#   'mileage': '23,687 Miles',
#   'mileage_unformatted': 23687,
#   'city': 'Livermore',
#   'state': 'CA',
#   'distance_from_origin': 33,
#   'dealer_name': 'Livermore Ford Lincoln',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1E22GF128581',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '309518509',
#    'remote_dealer_id': '286449',
#    'dealer_name': None,
#    'remote_sku': 'P8618',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '60D',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1629556087,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCAE23GF006652',
#   'vdp_url': '/tesla-model+x#vin=5YJXCAE23GF006652',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 225927079,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/21/04/18/2016_tesla_model_x-pic-1471908417969702557-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--tL0vIE6e--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/21/04/18/2016_tesla_model_x-pic-1471908417969702557-1024x768.jpeg',
#   'lat': 37.5043,
#   'lon': -122.248,
#   'year': 2016,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$69,799',
#   'price_unformatted': 69799,
#   'mileage': '42,976 Miles',
#   'mileage_unformatted': 42976,
#   'city': 'San Carlos',
#   'state': 'CA',
#   'distance_from_origin': 20,
#   'dealer_name': 'Z CARZ INC',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCAE23GF006652',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '310744852',
#    'remote_dealer_id': '343090',
#    'dealer_name': None,
#    'remote_sku': 'Z5328',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '90D',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1622731589,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCDE26KF182783',
#   'vdp_url': '/tesla-model+x#vin=5YJXCDE26KF182783',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 220394830,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/05/22/01/2019_tesla_model_x-pic-4929792636896690341-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--DAhc72uU--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/05/22/01/2019_tesla_model_x-pic-4929792636896690341-1024x768.jpeg',
#   'lat': 37.2793687062809,
#   'lon': -121.95494149607,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$79,899',
#   'price_unformatted': 79899,
#   'mileage': '9,108 Miles',
#   'mileage_unformatted': 9108,
#   'city': 'Campbell',
#   'state': 'CA',
#   'distance_from_origin': 42,
#   'dealer_name': 'Prestige Pre-Owned',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCDE26KF182783',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '304373975',
#    'remote_dealer_id': '341863',
#    'dealer_name': None,
#    'remote_sku': 'Consign',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard Range',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1627834723,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA3KF446556',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3KF446556',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224636651,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/15/05/46/2019_tesla_model_3-pic-7327959515489823717-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--kjvdAU1---/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/15/05/46/2019_tesla_model_3-pic-7327959515489823717-1024x768.jpeg',
#   'lat': 37.5879,
#   'lon': -122.362,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$39,500',
#   'price_unformatted': 39500,
#   'mileage': '18,982 Miles',
#   'mileage_unformatted': 18982,
#   'city': 'Burlingame',
#   'state': 'CA',
#   'distance_from_origin': 13,
#   'dealer_name': 'Porsche Audi Burlingame',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA3KF446556',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '309259156',
#    'remote_dealer_id': '312434',
#    'dealer_name': None,
#    'remote_sku': '2130B',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1628697305,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1H12EFP29862',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1H12EFP29862',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 225255947,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/11/03/20/2014_tesla_model_s-pic-2538277380164200276-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HxUp26kR--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/11/03/20/2014_tesla_model_s-pic-2538277380164200276-1024x768.jpeg',
#   'lat': 37.9367,
#   'lon': -122.051,
#   'year': 2014,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$35,950',
#   'price_unformatted': 35950,
#   'mileage': '134,940 Miles',
#   'mileage_unformatted': 134940,
#   'city': 'Walnut Creek',
#   'state': 'CA',
#   'distance_from_origin': 22,
#   'dealer_name': 'Walnut Creek Motor Cars',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1H12EFP29862',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '309944708',
#    'remote_dealer_id': '370667',
#    'dealer_name': None,
#    'remote_sku': '2147',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '85',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True}]

# %%
len(results_json)

#this shows we have made the right selection
# Out:
# 20

# %%
# now we need to grab the information we need for one of the cars
results_json[0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1623286982,
#  'recent_price_drop': False,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EA6KF483326',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6KF483326',
#  'clickoff_url': 'https://www.shift.com/car/c110936?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 220874699,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--1kW4bu47--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#  'lat': 37.6397,
#  'lon': -122.416,
#  'year': 2019,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$40,500',
#  'price_unformatted': 40500,
#  'mileage': '16,341 Miles',
#  'mileage_unformatted': 16341,
#  'city': 'South San Francisco',
#  'state': 'CA',
#  'distance_from_origin': 9,
#  'dealer_name': 'Shift SF - Test Drives Delivered To You',
#  'show_message_box': None,
#  'email_opt_default': True,
#  'show_financing_checkbox': None,
#  'show_new_mileage': False,
#  'show_thankyou_page': False,
#  'show_rsrp': True,
#  'click_off': False,
#  'pre_check_thankyou': True,
#  'cpl_value': 15,
#  'partner_type': 'dealer_direct',
#  'vin': '5YJ3E1EA6KF483326',
#  'provider': None,
#  'provider_name': 'car_gurus',
#  'always_ask_for_zip': False,
#  'listing_id': None,
#  'time_on_market': None,
#  'total_price_change': None,
#  'relative_price_difference': None,
#  'listimate_category': None,
#  'listimate_text': None,
#  'photo_urls': [],
#  'tracking_params': {'id_from_provider': '304931331',
#   'remote_dealer_id': '413397',
#   'dealer_name': 'Shift SF - Test Drives Delivered to You',
#   'remote_sku': 'c110936',
#   'experience': 'regional',
#   'rooftop_unique_name': None,
#   'rooftop_uuid': None,
#   'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#   'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#   'dealer_group_unique_name': 'shift_cargurus',
#   'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#  'trim': 'Standard Range Plus',
#  'provider_id': 199,
#  'provider_group_id': 231,
#  'experience': 'regional',
#  'regional': True,
#  'badges': {'position0': None, 'position1': None},
#  'quick_picks_eligible': False}

# %%
#model
results_json[0]["model"]
# Out:
# 'Model 3'

# %%
#mileage
results_json[0]["mileage"]
# Out:
# '16,341 Miles'

# %%
#year
results_json[0]["year"]
# Out:
# 2019

# %%
#dealer name
results_json[0]["dealer_name"]
# Out:
# 'Shift SF - Test Drives Delivered To You'

# %%
# price
results_json[0]["price"]
# Out:
# '$40,500'

# %% [markdown]
# ### 5.2. putting it all together and get the information automatically and store in dataframe

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []


for result in results_json:
    model.append(result["model"])
    mileage.append(result["mileage"])
    year.append(result["year"])
    dealer_name.append(result["dealer_name"])
    price.append(result["price"])

# %%
cars_df = pd.DataFrame ({"model": model,
                          "mileage": mileage,
                          "year": year,
                          "dealer_name": dealer_name,
                          "price": price})

# %%
cars_df
# Out:
#       model        mileage  year                              dealer_name  \
# 0   Model 3   16,341 Miles  2019  Shift SF - Test Drives Delivered To You
# 1   Model 3    1,339 Miles  2021             CarMax Pleasanton - Now Open
# 2   Model 3   32,407 Miles  2019  Shift SF - Test Drives Delivered To You
# 3   Model 3   46,517 Miles  2018  Shift SF - Test Drives Delivered To You
# 4   Model 3    9,350 Miles  2018                      San Jose Mitsubishi
# 5   Model Y   17,245 Miles  2020                Premier Nissan Of Fremont
# 6   Model 3   17,796 Miles  2020             CarMax Santa Rosa - Now Open
# 7   Model 3    6,416 Miles  2019                         Elite Motor Cars
# 8   Model 3   10,353 Miles  2020                CarMax Fremont - Now Open
# 9   Model 3   21,219 Miles  2019                             Audi Oakland
# 10  Model X   22,892 Miles  2018                Premier Nissan Of Fremont
# 11  Model 3    5,922 Miles  2021                CarMax Fremont - Now Open
# 12  Model X   23,731 Miles  2018                         Elite Motor Cars
# 13  Model 3   12,539 Miles  2020                    Volkswagen Of Oakland
# 14  Model 3   46,334 Miles  2019                            Oakland Acura
# 15  Model S   23,687 Miles  2016                   Livermore Ford Lincoln
# 16  Model X   42,976 Miles  2016                               Z CARZ INC
# 17  Model X    9,108 Miles  2019                       Prestige Pre-Owned
# 18  Model 3   18,982 Miles  2019                  Porsche Audi Burlingame
# 19  Model S  134,940 Miles  2014                  Walnut Creek Motor Cars
#
#       price
# 0   $40,500
# 1   $54,998
# 2   $41,950
# 3   $39,950
# 4   $46,999
# 5   $62,995
# 6   $58,998
# 7   $57,990
# 8   $61,998
# 9   $42,598
# 10  $77,995
# 11  $55,998
# 12  $80,990
# 13  $46,900
# 14  $40,480
# 15  $59,995
# 16  $69,799
# 17  $79,899
# 18  $39,500
# 19  $35,950

# %%
# store data of the single page to an excel file
cars_df.to_excel("singel_page_car.xlsx", index = False)

# %% [markdown]
# ### Scraping Multiple Pages

# %% [markdown]
# in "params" we have the page number so we can make a for loop to do the scraping for the number of pages we want

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'a05719cf-a626-4dee-bb98-bef4f39d375c',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzkyLjAuNDUxNS4xNTkgU2FmYXJpLzUzNy4zNiJ9; client_guid_timestamp=e02c9c83-67cd-4781-9710-2a0fb9ca8e20.1629563935984; scavenger-a493=...; _sp_ses.8ca5=*; _fbp=fb.1.1629563936393.301782673; _ga=GA1.2.1962975142.1629563934; _gid=GA1.2.809253866.1629563937; __gads=ID=2fecf3c5f98db8bc:T=1629563936:S=ALNI_MbP7Qh5aV67Y9ME82H_NbgP-TB1lg; _ga_152345333=GS1.1.1629563933.1.1.1629563988.0; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=c9711a73-266d-4daa-8d34-a5f4b1050171; _gcl_au=1.1.1968340282.1629564101; cto_bundle=e7B8Fl94MDdzUjRmcjFBSlZrekd2TyUyRmNzdEZYR0hiM3FNWVFYSHBqbUtJMjJVYzFNOERnOFBSelQlMkZIT3o4Z2Z2RjA0SCUyQjdmJTJCVVhBZmZnRUlFRERqUFp5NlBrVksxWjhsekp2b3ZSMm1UMHc1ajklMkZVbnoyS2lOYklnNVRiSmNTVSUyRlpnJTJCenRRd01nU1BSd2JGelFZNXZJQXNMZyUzRCUzRA; _gat=1; _sp_id.8ca5=c99d8079-5160-4a37-9ca1-0ef78843c81f.1629563936.1.1629564425.1629563936.faa2eb1c-9606-4e57-ab87-742b8c6e8ca9',
    'if-none-match': 'W/^\\^8dcb08c3d726a06db127e8ed93cf14d4^\\^',
}


model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(2,7):

    params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page',str(i) ),
    )

    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    json_response =response.json()
    results_json =json_response["search_results"]


    for result in results_json:
        model.append(result["model"])
        mileage.append(result["mileage"])
        year.append(result["year"])
        dealer_name.append(result["dealer_name"])
        price.append(result["price"])

# %% [markdown]
# ### Turning our data of multiple pages into a pandas dataframe

# %%
cars_multiple_df = pd.DataFrame ({"model": model,
                          "mileage": mileage,
                          "year": year,
                          "dealer_name": dealer_name,
                          "price": price})

# %% [markdown]
# ### Store results to excel

# %%
cars_multiple_df.to_excel("multiple_page_cars.xlsx", index = False)
